# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class', axis=1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdkfar20u
# INFO:tensorflow:Using config: {'_tf_random_seed': None, '_is_chief': True, '_task_id': 0, '_keep_checkpoint_max': 5, '_train_distribute': None, '_protocol': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa5168bab00>, '_evaluation_master': '', '_save_summary_steps': 100, '_service': None, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpdkfar20u', '_eval_distribute': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_device_fn': None, '_task_type': 'worker', '_num_worker_replicas': 1, '_num_ps_replicas': 0, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_experimental_distribute': None}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpdkfar20u/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 153.813
# INFO:tensorflow:loss = 6.195825, step = 101 (0.654 sec)
# INFO:tensorflow:global_step/sec: 236.535
# INFO:tensorflow:loss = 4.909428, step = 201 (0.439 sec)
# INFO:tensorflow:global_step/sec: 233.339
# INFO:tensorflow:loss = 4.3546295, step = 301 (0.416 sec)
# INFO:tensorflow:global_step/sec: 210.544
# INFO:tensorflow:loss = 6.611521, step = 401 (0.473 sec)
# INFO:tensorflow:global_step/sec: 198.998
# INFO:tensorflow:loss = 5.393735, step = 501 (0.529 sec)
# INFO:tensorflow:global_step/sec: 208.203
# INFO:tensorflow:loss = 5.9574356, step = 601 (0.453 sec)
# INFO:tensorflow:global_step/sec: 219.161
# INFO:tensorflow:loss = 6.60416, step = 701 (0.456 sec)
# INFO:tensorflow:global_step/sec: 222.608
# INFO:tensorflow:loss = 6.934543, step = 801 (0.452 sec)
# INFO:tensorflow:global_step/sec: 219.069
# INFO:tensorflow:loss = 4.5683537, step = 901 (0.454 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpdkfar20u/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.7674084.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-22T22:07:52Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdkfar20u/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-22-22:07:53
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72047246, accuracy_baseline = 0.65748036, auc = 0.7888706, auc_precision_recall = 0.6295035, average_loss = 0.5315238, global_step = 1000, label/mean = 0.34251967, loss = 5.192579, precision = 0.6, prediction/mean = 0.37582952, recall = 0.55172414
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpdkfar20u/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7888706,
#  'auc_precision_recall': 0.6295035,
#  'average_loss': 0.5315238,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.192579,
#  'precision': 0.6,
#  'prediction/mean': 0.37582952,
#  'recall': 0.55172414}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdkfar20u/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53775156], dtype=float32),
#   'logits': array([0.15129411], dtype=float32),
#   'probabilities': array([0.46224844, 0.53775156], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6489706], dtype=float32),
#   'logits': array([0.61451745], dtype=float32),
#   'probabilities': array([0.3510294, 0.6489706], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3839786], dtype=float32),
#   'logits': array([-0.47269493], dtype=float32),
#   'probabilities': array([0.6160214, 0.3839786], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32669014], dtype=float32),
#   'logits': array([-0.72319347], dtype=float32),
#   'probabilities': array([0.67330986, 0.32669017], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1411196], dtype=float32),
#   'logits': array([-1.8060219], dtype=float32),
#   'probabilities': array([0.85888046, 0.14111961], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7165738], dtype=float32),
#   'logits': array([0.92752945], dtype=float32),
#   'probabilities': array([0.2834262, 0.7165738], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6118093], dtype=float32),
#   'logits': array([0.454924], dtype=float32),
#   'probabilities': array([0.3881907, 0.6118093], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3537077], dtype=float32),
#   'logits': array([-0.60278106], dtype=float32),
#   'probabilities': array([0.6462923, 0.3537077], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24559408], dtype=float32),
#   'logits': array([-1.1222503], dtype=float32),
#   'probabilities': array([0.7544059 , 0.24559411], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24859875], dtype=float32),
#   'logits': array([-1.1060996], dtype=float32),
#   'probabilities': array([0.75140125, 0.24859875], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1291464], dtype=float32),
#   'logits': array([-1.9085269], dtype=float32),
#   'probabilities': array([0.87085354, 0.12914643], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15046883], dtype=float32),
#   'logits': array([-1.7309285], dtype=float32),
#   'probabilities': array([0.8495312 , 0.15046886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29983014], dtype=float32),
#   'logits': array([-0.8481069], dtype=float32),
#   'probabilities': array([0.70016986, 0.2998301 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5950127], dtype=float32),
#   'logits': array([0.38472712], dtype=float32),
#   'probabilities': array([0.40498728, 0.5950127 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17723012], dtype=float32),
#   'logits': array([-1.5352277], dtype=float32),
#   'probabilities': array([0.8227699, 0.1772301], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33285004], dtype=float32),
#   'logits': array([-0.69532275], dtype=float32),
#   'probabilities': array([0.66714996, 0.33285007], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3783211], dtype=float32),
#   'logits': array([-0.49668038], dtype=float32),
#   'probabilities': array([0.6216789, 0.3783211], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1305311], dtype=float32),
#   'logits': array([-1.8962712], dtype=float32),
#   'probabilities': array([0.86946887, 0.13053107], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.369505], dtype=float32),
#   'logits': array([-0.534341], dtype=float32),
#   'probabilities': array([0.630495  , 0.36950502], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13446593], dtype=float32),
#   'logits': array([-1.8620359], dtype=float32),
#   'probabilities': array([0.86553407, 0.13446593], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21967593], dtype=float32),
#   'logits': array([-1.2675558], dtype=float32),
#   'probabilities': array([0.7803241 , 0.21967594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30953354], dtype=float32),
#   'logits': array([-0.8023011], dtype=float32),
#   'probabilities': array([0.6904665, 0.3095335], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6790202], dtype=float32),
#   'logits': array([0.74927294], dtype=float32),
#   'probabilities': array([0.3209797, 0.6790202], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21476936], dtype=float32),
#   'logits': array([-1.2964127], dtype=float32),
#   'probabilities': array([0.78523064, 0.21476938], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17494169], dtype=float32),
#   'logits': array([-1.5510013], dtype=float32),
#   'probabilities': array([0.82505834, 0.1749417 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78520226], dtype=float32),
#   'logits': array([1.2962445], dtype=float32),
#   'probabilities': array([0.21479775, 0.78520226], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18468413], dtype=float32),
#   'logits': array([-1.4849284], dtype=float32),
#   'probabilities': array([0.8153158 , 0.18468417], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32045457], dtype=float32),
#   'logits': array([-0.75168365], dtype=float32),
#   'probabilities': array([0.67954546, 0.32045457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10155179], dtype=float32),
#   'logits': array([-2.1801002], dtype=float32),
#   'probabilities': array([0.8984482 , 0.10155179], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60411394], dtype=float32),
#   'logits': array([0.4226364], dtype=float32),
#   'probabilities': array([0.39588606, 0.60411394], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.95034575], dtype=float32),
#   'logits': array([2.9517417], dtype=float32),
#   'probabilities': array([0.04965426, 0.95034575], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41520777], dtype=float32),
#   'logits': array([-0.34247756], dtype=float32),
#   'probabilities': array([0.5847922 , 0.41520774], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31507197], dtype=float32),
#   'logits': array([-0.77651274], dtype=float32),
#   'probabilities': array([0.684928  , 0.31507194], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58223474], dtype=float32),
#   'logits': array([0.331954], dtype=float32),
#   'probabilities': array([0.4177653 , 0.58223474], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2441541], dtype=float32),
#   'logits': array([-1.1300379], dtype=float32),
#   'probabilities': array([0.75584596, 0.24415411], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37932825], dtype=float32),
#   'logits': array([-0.49240047], dtype=float32),
#   'probabilities': array([0.62067175, 0.37932822], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53281885], dtype=float32),
#   'logits': array([0.13146436], dtype=float32),
#   'probabilities': array([0.4671812 , 0.53281885], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65355897], dtype=float32),
#   'logits': array([0.6347202], dtype=float32),
#   'probabilities': array([0.346441  , 0.65355897], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77441794], dtype=float32),
#   'logits': array([1.2334274], dtype=float32),
#   'probabilities': array([0.22558212, 0.77441794], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3276561], dtype=float32),
#   'logits': array([-0.71880543], dtype=float32),
#   'probabilities': array([0.6723439, 0.3276561], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18466672], dtype=float32),
#   'logits': array([-1.4850442], dtype=float32),
#   'probabilities': array([0.8153333 , 0.18466672], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56180406], dtype=float32),
#   'logits': array([0.24848711], dtype=float32),
#   'probabilities': array([0.43819588, 0.56180406], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14697477], dtype=float32),
#   'logits': array([-1.758528], dtype=float32),
#   'probabilities': array([0.8530252 , 0.14697479], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54899096], dtype=float32),
#   'logits': array([0.19659472], dtype=float32),
#   'probabilities': array([0.451009  , 0.54899096], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13550523], dtype=float32),
#   'logits': array([-1.8531351], dtype=float32),
#   'probabilities': array([0.8644948 , 0.13550523], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10195032], dtype=float32),
#   'logits': array([-2.1757395], dtype=float32),
#   'probabilities': array([0.89804965, 0.10195034], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61285657], dtype=float32),
#   'logits': array([0.45933568], dtype=float32),
#   'probabilities': array([0.3871434 , 0.61285657], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18501836], dtype=float32),
#   'logits': array([-1.4827105], dtype=float32),
#   'probabilities': array([0.8149817 , 0.18501838], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20246601], dtype=float32),
#   'logits': array([-1.3709525], dtype=float32),
#   'probabilities': array([0.79753405, 0.20246601], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1168381], dtype=float32),
#   'logits': array([-2.0227194], dtype=float32),
#   'probabilities': array([0.8831619, 0.1168381], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16417292], dtype=float32),
#   'logits': array([-1.6275016], dtype=float32),
#   'probabilities': array([0.83582705, 0.16417289], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25478595], dtype=float32),
#   'logits': array([-1.0732477], dtype=float32),
#   'probabilities': array([0.74521405, 0.25478595], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25085968], dtype=float32),
#   'logits': array([-1.0940328], dtype=float32),
#   'probabilities': array([0.7491404 , 0.25085965], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38778603], dtype=float32),
#   'logits': array([-0.45662808], dtype=float32),
#   'probabilities': array([0.6122139, 0.387786 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12635496], dtype=float32),
#   'logits': array([-1.933579], dtype=float32),
#   'probabilities': array([0.87364507, 0.12635498], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21719089], dtype=float32),
#   'logits': array([-1.2821121], dtype=float32),
#   'probabilities': array([0.7828091, 0.2171909], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20593372], dtype=float32),
#   'logits': array([-1.3496125], dtype=float32),
#   'probabilities': array([0.79406625, 0.20593372], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21646082], dtype=float32),
#   'logits': array([-1.2864114], dtype=float32),
#   'probabilities': array([0.7835392 , 0.21646085], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49900207], dtype=float32),
#   'logits': array([-0.00399172], dtype=float32),
#   'probabilities': array([0.5009979 , 0.49900204], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.157357], dtype=float32),
#   'logits': array([-1.6780262], dtype=float32),
#   'probabilities': array([0.842643, 0.157357], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2401576], dtype=float32),
#   'logits': array([-1.1518157], dtype=float32),
#   'probabilities': array([0.75984234, 0.24015759], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6676464], dtype=float32),
#   'logits': array([0.6975595], dtype=float32),
#   'probabilities': array([0.33235356, 0.66764647], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65593004], dtype=float32),
#   'logits': array([0.6452093], dtype=float32),
#   'probabilities': array([0.34406993, 0.65593004], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52750456], dtype=float32),
#   'logits': array([0.11012948], dtype=float32),
#   'probabilities': array([0.4724954 , 0.52750456], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3558191], dtype=float32),
#   'logits': array([-0.59355706], dtype=float32),
#   'probabilities': array([0.6441809, 0.3558191], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49064836], dtype=float32),
#   'logits': array([-0.03741097], dtype=float32),
#   'probabilities': array([0.5093517, 0.4906484], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1792739], dtype=float32),
#   'logits': array([-1.5212746], dtype=float32),
#   'probabilities': array([0.8207261 , 0.17927392], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1930837], dtype=float32),
#   'logits': array([-1.4300961], dtype=float32),
#   'probabilities': array([0.8069163, 0.1930837], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15704681], dtype=float32),
#   'logits': array([-1.6803675], dtype=float32),
#   'probabilities': array([0.84295315, 0.15704681], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12454616], dtype=float32),
#   'logits': array([-1.950066], dtype=float32),
#   'probabilities': array([0.8754538 , 0.12454616], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6230686], dtype=float32),
#   'logits': array([0.5025933], dtype=float32),
#   'probabilities': array([0.37693143, 0.6230686 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23097566], dtype=float32),
#   'logits': array([-1.2028102], dtype=float32),
#   'probabilities': array([0.7690243 , 0.23097569], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4334153], dtype=float32),
#   'logits': array([-0.2679302], dtype=float32),
#   'probabilities': array([0.5665847, 0.4334153], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5906459], dtype=float32),
#   'logits': array([0.36663616], dtype=float32),
#   'probabilities': array([0.4093541, 0.5906459], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.308471], dtype=float32),
#   'logits': array([-0.80727726], dtype=float32),
#   'probabilities': array([0.69152904, 0.308471  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67022055], dtype=float32),
#   'logits': array([0.70918286], dtype=float32),
#   'probabilities': array([0.32977942, 0.67022055], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12263018], dtype=float32),
#   'logits': array([-1.967755], dtype=float32),
#   'probabilities': array([0.87736976, 0.12263023], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6307406], dtype=float32),
#   'logits': array([0.5353954], dtype=float32),
#   'probabilities': array([0.3692594 , 0.63074064], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1232166], dtype=float32),
#   'logits': array([-1.9623163], dtype=float32),
#   'probabilities': array([0.87678343, 0.1232166 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5725805], dtype=float32),
#   'logits': array([0.2923875], dtype=float32),
#   'probabilities': array([0.42741945, 0.5725805 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33844775], dtype=float32),
#   'logits': array([-0.6702193], dtype=float32),
#   'probabilities': array([0.66155225, 0.33844775], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16030246], dtype=float32),
#   'logits': array([-1.6559794], dtype=float32),
#   'probabilities': array([0.83969754, 0.16030245], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5746836], dtype=float32),
#   'logits': array([0.3009863], dtype=float32),
#   'probabilities': array([0.4253164, 0.5746836], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60247064], dtype=float32),
#   'logits': array([0.41577017], dtype=float32),
#   'probabilities': array([0.39752933, 0.60247064], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56516206], dtype=float32),
#   'logits': array([0.2621392], dtype=float32),
#   'probabilities': array([0.4348379 , 0.56516206], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17091793], dtype=float32),
#   'logits': array([-1.5791355], dtype=float32),
#   'probabilities': array([0.829082  , 0.17091793], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3505175], dtype=float32),
#   'logits': array([-0.6167653], dtype=float32),
#   'probabilities': array([0.6494825 , 0.35051748], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15406924], dtype=float32),
#   'logits': array([-1.7030354], dtype=float32),
#   'probabilities': array([0.84593076, 0.15406924], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7209356], dtype=float32),
#   'logits': array([0.94910705], dtype=float32),
#   'probabilities': array([0.27906445, 0.7209356 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8243898], dtype=float32),
#   'logits': array([1.5463768], dtype=float32),
#   'probabilities': array([0.17561018, 0.8243898 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6288419], dtype=float32),
#   'logits': array([0.5272517], dtype=float32),
#   'probabilities': array([0.37115812, 0.6288419 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2123974], dtype=float32),
#   'logits': array([-1.3105347], dtype=float32),
#   'probabilities': array([0.7876026 , 0.21239738], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46135172], dtype=float32),
#   'logits': array([-0.15490216], dtype=float32),
#   'probabilities': array([0.5386483 , 0.46135172], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37995827], dtype=float32),
#   'logits': array([-0.48972547], dtype=float32),
#   'probabilities': array([0.6200417, 0.3799582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45912373], dtype=float32),
#   'logits': array([-0.16387081], dtype=float32),
#   'probabilities': array([0.54087627, 0.45912373], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35337332], dtype=float32),
#   'logits': array([-0.6042442], dtype=float32),
#   'probabilities': array([0.6466267 , 0.35337332], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46087486], dtype=float32),
#   'logits': array([-0.15682125], dtype=float32),
#   'probabilities': array([0.53912514, 0.46087483], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1523202], dtype=float32),
#   'logits': array([-1.7165182], dtype=float32),
#   'probabilities': array([0.8476798 , 0.15232019], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58188057], dtype=float32),
#   'logits': array([0.3304981], dtype=float32),
#   'probabilities': array([0.41811943, 0.58188057], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5831103], dtype=float32),
#   'logits': array([0.33555448], dtype=float32),
#   'probabilities': array([0.41688976, 0.5831103 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2411522], dtype=float32),
#   'logits': array([-1.146373], dtype=float32),
#   'probabilities': array([0.75884783, 0.2411522 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17450595], dtype=float32),
#   'logits': array([-1.5540233], dtype=float32),
#   'probabilities': array([0.82549405, 0.17450593], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17645004], dtype=float32),
#   'logits': array([-1.5405864], dtype=float32),
#   'probabilities': array([0.8235499 , 0.17645004], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.276616], dtype=float32),
#   'logits': array([-0.9613099], dtype=float32),
#   'probabilities': array([0.72338396, 0.276616  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39955565], dtype=float32),
#   'logits': array([-0.40731692], dtype=float32),
#   'probabilities': array([0.6004443 , 0.39955562], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13111585], dtype=float32),
#   'logits': array([-1.8911287], dtype=float32),
#   'probabilities': array([0.86888415, 0.13111582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32543516], dtype=float32),
#   'logits': array([-0.7289045], dtype=float32),
#   'probabilities': array([0.6745648 , 0.32543516], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23872128], dtype=float32),
#   'logits': array([-1.1597028], dtype=float32),
#   'probabilities': array([0.76127875, 0.23872131], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09640256], dtype=float32),
#   'logits': array([-2.2378511], dtype=float32),
#   'probabilities': array([0.9035974 , 0.09640256], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12283868], dtype=float32),
#   'logits': array([-1.965819], dtype=float32),
#   'probabilities': array([0.8771613 , 0.12283868], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7531891], dtype=float32),
#   'logits': array([1.1156939], dtype=float32),
#   'probabilities': array([0.2468109 , 0.75318915], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18157345], dtype=float32),
#   'logits': array([-1.5057235], dtype=float32),
#   'probabilities': array([0.81842655, 0.18157344], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12761071], dtype=float32),
#   'logits': array([-1.922251], dtype=float32),
#   'probabilities': array([0.87238926, 0.12761077], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14214021], dtype=float32),
#   'logits': array([-1.7976265], dtype=float32),
#   'probabilities': array([0.85785973, 0.14214022], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49665916], dtype=float32),
#   'logits': array([-0.0133636], dtype=float32),
#   'probabilities': array([0.50334084, 0.49665913], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48455176], dtype=float32),
#   'logits': array([-0.06181264], dtype=float32),
#   'probabilities': array([0.5154483, 0.4845518], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24428344], dtype=float32),
#   'logits': array([-1.1293373], dtype=float32),
#   'probabilities': array([0.75571656, 0.24428342], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44020146], dtype=float32),
#   'logits': array([-0.24034452], dtype=float32),
#   'probabilities': array([0.55979854, 0.44020146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17842387], dtype=float32),
#   'logits': array([-1.5270627], dtype=float32),
#   'probabilities': array([0.8215762 , 0.17842387], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22361383], dtype=float32),
#   'logits': array([-1.2447294], dtype=float32),
#   'probabilities': array([0.77638614, 0.22361383], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5164942], dtype=float32),
#   'logits': array([0.0660007], dtype=float32),
#   'probabilities': array([0.4835058 , 0.51649415], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48862126], dtype=float32),
#   'logits': array([-0.04552281], dtype=float32),
#   'probabilities': array([0.51137877, 0.4886213 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1349785], dtype=float32),
#   'logits': array([-1.8576391], dtype=float32),
#   'probabilities': array([0.8650216 , 0.13497849], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41537714], dtype=float32),
#   'logits': array([-0.34178007], dtype=float32),
#   'probabilities': array([0.58462286, 0.4153771 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6984856], dtype=float32),
#   'logits': array([0.84009707], dtype=float32),
#   'probabilities': array([0.30151433, 0.6984857 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5479628], dtype=float32),
#   'logits': array([0.1924429], dtype=float32),
#   'probabilities': array([0.4520372, 0.5479628], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39686403], dtype=float32),
#   'logits': array([-0.418549], dtype=float32),
#   'probabilities': array([0.60313594, 0.396864  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5617845], dtype=float32),
#   'logits': array([0.2484076], dtype=float32),
#   'probabilities': array([0.43821546, 0.5617845 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23514614], dtype=float32),
#   'logits': array([-1.1794776], dtype=float32),
#   'probabilities': array([0.76485384, 0.23514612], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1888128], dtype=float32),
#   'logits': array([-1.4577427], dtype=float32),
#   'probabilities': array([0.81118715, 0.1888128 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12805414], dtype=float32),
#   'logits': array([-1.9182737], dtype=float32),
#   'probabilities': array([0.8719458, 0.1280542], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27413997], dtype=float32),
#   'logits': array([-0.9737184], dtype=float32),
#   'probabilities': array([0.72586006, 0.27413997], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4985704], dtype=float32),
#   'logits': array([-0.00571835], dtype=float32),
#   'probabilities': array([0.50142956, 0.49857038], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69859207], dtype=float32),
#   'logits': array([0.8406024], dtype=float32),
#   'probabilities': array([0.30140793, 0.69859207], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.229765], dtype=float32),
#   'logits': array([-1.2096387], dtype=float32),
#   'probabilities': array([0.770235  , 0.22976498], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16305861], dtype=float32),
#   'logits': array([-1.6356441], dtype=float32),
#   'probabilities': array([0.83694136, 0.16305864], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41522795], dtype=float32),
#   'logits': array([-0.34239447], dtype=float32),
#   'probabilities': array([0.58477205, 0.41522795], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2373231], dtype=float32),
#   'logits': array([-1.1674119], dtype=float32),
#   'probabilities': array([0.76267684, 0.23732309], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14631186], dtype=float32),
#   'logits': array([-1.7638255], dtype=float32),
#   'probabilities': array([0.8536882 , 0.14631188], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17950492], dtype=float32),
#   'logits': array([-1.5197053], dtype=float32),
#   'probabilities': array([0.82049507, 0.17950492], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12388006], dtype=float32),
#   'logits': array([-1.9561889], dtype=float32),
#   'probabilities': array([0.8761199 , 0.12388009], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39810607], dtype=float32),
#   'logits': array([-0.4133628], dtype=float32),
#   'probabilities': array([0.60189396, 0.39810607], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78459555], dtype=float32),
#   'logits': array([1.2926508], dtype=float32),
#   'probabilities': array([0.21540447, 0.7845955 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78872395], dtype=float32),
#   'logits': array([1.3172508], dtype=float32),
#   'probabilities': array([0.21127605, 0.788724  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56062645], dtype=float32),
#   'logits': array([0.24370492], dtype=float32),
#   'probabilities': array([0.43937352, 0.56062645], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5143338], dtype=float32),
#   'logits': array([0.05735075], dtype=float32),
#   'probabilities': array([0.48566628, 0.5143338 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5849903], dtype=float32),
#   'logits': array([0.34329355], dtype=float32),
#   'probabilities': array([0.41500965, 0.5849903 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1137006], dtype=float32),
#   'logits': array([-2.0534856], dtype=float32),
#   'probabilities': array([0.8862994 , 0.11370065], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5495436], dtype=float32),
#   'logits': array([0.19882691], dtype=float32),
#   'probabilities': array([0.45045638, 0.5495436 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77123916], dtype=float32),
#   'logits': array([1.2153214], dtype=float32),
#   'probabilities': array([0.22876084, 0.77123916], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42330915], dtype=float32),
#   'logits': array([-0.30920362], dtype=float32),
#   'probabilities': array([0.57669085, 0.42330915], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26956603], dtype=float32),
#   'logits': array([-0.9968255], dtype=float32),
#   'probabilities': array([0.730434  , 0.26956603], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35563326], dtype=float32),
#   'logits': array([-0.59436816], dtype=float32),
#   'probabilities': array([0.6443668 , 0.35563323], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6005393], dtype=float32),
#   'logits': array([0.4077127], dtype=float32),
#   'probabilities': array([0.3994607, 0.6005393], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2446551], dtype=float32),
#   'logits': array([-1.127325], dtype=float32),
#   'probabilities': array([0.75534487, 0.24465507], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66852725], dtype=float32),
#   'logits': array([0.70153177], dtype=float32),
#   'probabilities': array([0.33147267, 0.66852725], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41942668], dtype=float32),
#   'logits': array([-0.32512742], dtype=float32),
#   'probabilities': array([0.5805734, 0.4194267], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43070364], dtype=float32),
#   'logits': array([-0.27898097], dtype=float32),
#   'probabilities': array([0.56929636, 0.4307036 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16461544], dtype=float32),
#   'logits': array([-1.6242801], dtype=float32),
#   'probabilities': array([0.8353846 , 0.16461544], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18327443], dtype=float32),
#   'logits': array([-1.4943185], dtype=float32),
#   'probabilities': array([0.81672555, 0.18327443], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18814737], dtype=float32),
#   'logits': array([-1.4620934], dtype=float32),
#   'probabilities': array([0.81185263, 0.18814737], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44357994], dtype=float32),
#   'logits': array([-0.22664553], dtype=float32),
#   'probabilities': array([0.5564201 , 0.44357994], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14985889], dtype=float32),
#   'logits': array([-1.7357082], dtype=float32),
#   'probabilities': array([0.85014117, 0.1498589 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7449485], dtype=float32),
#   'logits': array([1.0718497], dtype=float32),
#   'probabilities': array([0.2550515 , 0.74494857], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20991188], dtype=float32),
#   'logits': array([-1.3254569], dtype=float32),
#   'probabilities': array([0.7900882 , 0.20991187], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5149724], dtype=float32),
#   'logits': array([0.05990744], dtype=float32),
#   'probabilities': array([0.48502764, 0.5149724 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15488058], dtype=float32),
#   'logits': array([-1.6968235], dtype=float32),
#   'probabilities': array([0.8451194, 0.1548806], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69378257], dtype=float32),
#   'logits': array([0.81786335], dtype=float32),
#   'probabilities': array([0.3062174, 0.6937826], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3299411], dtype=float32),
#   'logits': array([-0.70845145], dtype=float32),
#   'probabilities': array([0.6700589 , 0.32994112], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19106191], dtype=float32),
#   'logits': array([-1.4431248], dtype=float32),
#   'probabilities': array([0.8089381 , 0.19106193], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34695977], dtype=float32),
#   'logits': array([-0.63242996], dtype=float32),
#   'probabilities': array([0.6530403 , 0.34695977], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34230214], dtype=float32),
#   'logits': array([-0.65305203], dtype=float32),
#   'probabilities': array([0.6576979 , 0.34230208], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16011998], dtype=float32),
#   'logits': array([-1.6573355], dtype=float32),
#   'probabilities': array([0.83988, 0.16012], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71869415], dtype=float32),
#   'logits': array([0.9379934], dtype=float32),
#   'probabilities': array([0.28130582, 0.71869415], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1882295], dtype=float32),
#   'logits': array([-1.4615556], dtype=float32),
#   'probabilities': array([0.8117705 , 0.18822952], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16537014], dtype=float32),
#   'logits': array([-1.6188021], dtype=float32),
#   'probabilities': array([0.8346299 , 0.16537015], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27027303], dtype=float32),
#   'logits': array([-0.99323785], dtype=float32),
#   'probabilities': array([0.72972697, 0.270273  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43826], dtype=float32),
#   'logits': array([-0.24822682], dtype=float32),
#   'probabilities': array([0.56174004, 0.43826002], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27615324], dtype=float32),
#   'logits': array([-0.9636238], dtype=float32),
#   'probabilities': array([0.72384673, 0.27615324], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11726509], dtype=float32),
#   'logits': array([-2.0185878], dtype=float32),
#   'probabilities': array([0.88273495, 0.1172651 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8484201], dtype=float32),
#   'logits': array([1.7222627], dtype=float32),
#   'probabilities': array([0.15157995, 0.84842   ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69332635], dtype=float32),
#   'logits': array([0.81571674], dtype=float32),
#   'probabilities': array([0.30667365, 0.69332635], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52667713], dtype=float32),
#   'logits': array([0.10680985], dtype=float32),
#   'probabilities': array([0.47332293, 0.52667713], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73971987], dtype=float32),
#   'logits': array([1.0445133], dtype=float32),
#   'probabilities': array([0.2602801, 0.7397199], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11264253], dtype=float32),
#   'logits': array([-2.0640285], dtype=float32),
#   'probabilities': array([0.8873575 , 0.11264254], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14641568], dtype=float32),
#   'logits': array([-1.7629945], dtype=float32),
#   'probabilities': array([0.8535843, 0.1464157], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21333247], dtype=float32),
#   'logits': array([-1.3049538], dtype=float32),
#   'probabilities': array([0.7866675 , 0.21333249], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33732516], dtype=float32),
#   'logits': array([-0.6752372], dtype=float32),
#   'probabilities': array([0.6626749 , 0.33732516], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3864596], dtype=float32),
#   'logits': array([-0.46221882], dtype=float32),
#   'probabilities': array([0.6135404, 0.3864596], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5842031], dtype=float32),
#   'logits': array([0.3400519], dtype=float32),
#   'probabilities': array([0.41579688, 0.5842031 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5720475], dtype=float32),
#   'logits': array([0.29020977], dtype=float32),
#   'probabilities': array([0.4279525, 0.5720475], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39404538], dtype=float32),
#   'logits': array([-0.4303391], dtype=float32),
#   'probabilities': array([0.60595465, 0.39404538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36040086], dtype=float32),
#   'logits': array([-0.57362485], dtype=float32),
#   'probabilities': array([0.6395992 , 0.36040083], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3478552], dtype=float32),
#   'logits': array([-0.62848043], dtype=float32),
#   'probabilities': array([0.65214485, 0.34785518], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18340963], dtype=float32),
#   'logits': array([-1.4934155], dtype=float32),
#   'probabilities': array([0.81659037, 0.18340965], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6475485], dtype=float32),
#   'logits': array([0.6082808], dtype=float32),
#   'probabilities': array([0.3524515 , 0.64754856], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12787607], dtype=float32),
#   'logits': array([-1.9198697], dtype=float32),
#   'probabilities': array([0.87212384, 0.12787609], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25546378], dtype=float32),
#   'logits': array([-1.0696809], dtype=float32),
#   'probabilities': array([0.7445362 , 0.25546378], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5498873], dtype=float32),
#   'logits': array([0.20021534], dtype=float32),
#   'probabilities': array([0.4501127, 0.5498873], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3607765], dtype=float32),
#   'logits': array([-0.5719955], dtype=float32),
#   'probabilities': array([0.6392235, 0.3607765], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18953696], dtype=float32),
#   'logits': array([-1.4530216], dtype=float32),
#   'probabilities': array([0.8104631 , 0.18953697], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27368554], dtype=float32),
#   'logits': array([-0.97600335], dtype=float32),
#   'probabilities': array([0.7263144 , 0.27368551], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26767623], dtype=float32),
#   'logits': array([-1.0064445], dtype=float32),
#   'probabilities': array([0.7323237 , 0.26767623], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13619512], dtype=float32),
#   'logits': array([-1.8472583], dtype=float32),
#   'probabilities': array([0.8638049 , 0.13619512], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19277078], dtype=float32),
#   'logits': array([-1.4321059], dtype=float32),
#   'probabilities': array([0.8072292 , 0.19277076], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59544283], dtype=float32),
#   'logits': array([0.3865124], dtype=float32),
#   'probabilities': array([0.40455714, 0.59544283], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7014338], dtype=float32),
#   'logits': array([0.8541347], dtype=float32),
#   'probabilities': array([0.29856625, 0.7014338 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64478874], dtype=float32),
#   'logits': array([0.59621024], dtype=float32),
#   'probabilities': array([0.35521123, 0.6447888 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70886785], dtype=float32),
#   'logits': array([0.88989174], dtype=float32),
#   'probabilities': array([0.29113218, 0.70886785], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46165177], dtype=float32),
#   'logits': array([-0.15369469], dtype=float32),
#   'probabilities': array([0.5383482 , 0.46165177], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30248028], dtype=float32),
#   'logits': array([-0.83551466], dtype=float32),
#   'probabilities': array([0.6975197 , 0.30248028], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52585775], dtype=float32),
#   'logits': array([0.10352325], dtype=float32),
#   'probabilities': array([0.4741423 , 0.52585775], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18456095], dtype=float32),
#   'logits': array([-1.4857471], dtype=float32),
#   'probabilities': array([0.8154391 , 0.18456092], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14791772], dtype=float32),
#   'logits': array([-1.7510269], dtype=float32),
#   'probabilities': array([0.8520823 , 0.14791773], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1850251], dtype=float32),
#   'logits': array([-1.4826658], dtype=float32),
#   'probabilities': array([0.81497484, 0.1850251 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5204868], dtype=float32),
#   'logits': array([0.0819931], dtype=float32),
#   'probabilities': array([0.47951323, 0.52048683], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05804136], dtype=float32),
#   'logits': array([-2.7868052], dtype=float32),
#   'probabilities': array([0.94195867, 0.05804138], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29044938], dtype=float32),
#   'logits': array([-0.89320266], dtype=float32),
#   'probabilities': array([0.7095507 , 0.29044935], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16122867], dtype=float32),
#   'logits': array([-1.6491144], dtype=float32),
#   'probabilities': array([0.8387713 , 0.16122867], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26381794], dtype=float32),
#   'logits': array([-1.0262183], dtype=float32),
#   'probabilities': array([0.7361821 , 0.26381794], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24600458], dtype=float32),
#   'logits': array([-1.1200361], dtype=float32),
#   'probabilities': array([0.7539954, 0.2460046], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28367448], dtype=float32),
#   'logits': array([-0.92630744], dtype=float32),
#   'probabilities': array([0.7163256 , 0.28367448], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79135525], dtype=float32),
#   'logits': array([1.3331138], dtype=float32),
#   'probabilities': array([0.20864478, 0.79135525], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17077431], dtype=float32),
#   'logits': array([-1.5801494], dtype=float32),
#   'probabilities': array([0.8292257 , 0.17077434], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11884934], dtype=float32),
#   'logits': array([-2.0033717], dtype=float32),
#   'probabilities': array([0.88115066, 0.11884937], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6105679], dtype=float32),
#   'logits': array([0.44970012], dtype=float32),
#   'probabilities': array([0.38943207, 0.6105679 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47793078], dtype=float32),
#   'logits': array([-0.08833432], dtype=float32),
#   'probabilities': array([0.5220692 , 0.47793075], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86013234], dtype=float32),
#   'logits': array([1.8163892], dtype=float32),
#   'probabilities': array([0.1398677, 0.8601323], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64779586], dtype=float32),
#   'logits': array([0.60936487], dtype=float32),
#   'probabilities': array([0.35220408, 0.64779586], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11904876], dtype=float32),
#   'logits': array([-2.0014691], dtype=float32),
#   'probabilities': array([0.8809512 , 0.11904876], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.649736], dtype=float32),
#   'logits': array([0.61787903], dtype=float32),
#   'probabilities': array([0.35026398, 0.64973605], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.551897], dtype=float32),
#   'logits': array([0.20833826], dtype=float32),
#   'probabilities': array([0.448103, 0.551897], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7896743], dtype=float32),
#   'logits': array([1.3229634], dtype=float32),
#   'probabilities': array([0.21032569, 0.78967434], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23499775], dtype=float32),
#   'logits': array([-1.1803029], dtype=float32),
#   'probabilities': array([0.76500225, 0.23499773], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17546466], dtype=float32),
#   'logits': array([-1.5473824], dtype=float32),
#   'probabilities': array([0.8245353 , 0.17546465], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55243397], dtype=float32),
#   'logits': array([0.21050978], dtype=float32),
#   'probabilities': array([0.44756606, 0.55243397], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1527763], dtype=float32),
#   'logits': array([-1.7129898], dtype=float32),
#   'probabilities': array([0.84722364, 0.15277632], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7896087], dtype=float32),
#   'logits': array([1.3225683], dtype=float32),
#   'probabilities': array([0.21039131, 0.78960866], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5514312], dtype=float32),
#   'logits': array([0.20645487], dtype=float32),
#   'probabilities': array([0.44856885, 0.5514312 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1697381], dtype=float32),
#   'logits': array([-1.5874846], dtype=float32),
#   'probabilities': array([0.83026195, 0.1697381 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5569706], dtype=float32),
#   'logits': array([0.22887635], dtype=float32),
#   'probabilities': array([0.44302937, 0.5569706 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48121262], dtype=float32),
#   'logits': array([-0.07518494], dtype=float32),
#   'probabilities': array([0.5187874, 0.4812126], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10489735], dtype=float32),
#   'logits': array([-2.1439562], dtype=float32),
#   'probabilities': array([0.8951026 , 0.10489734], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52568185], dtype=float32),
#   'logits': array([0.10281801], dtype=float32),
#   'probabilities': array([0.4743181 , 0.52568185], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60829425], dtype=float32),
#   'logits': array([0.440148], dtype=float32),
#   'probabilities': array([0.39170566, 0.60829425], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76368034], dtype=float32),
#   'logits': array([1.172964], dtype=float32),
#   'probabilities': array([0.23631965, 0.76368034], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8150076], dtype=float32),
#   'logits': array([1.4828829], dtype=float32),
#   'probabilities': array([0.18499237, 0.8150076 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4411667], dtype=float32),
#   'logits': array([-0.2364285], dtype=float32),
#   'probabilities': array([0.5588333 , 0.44116664], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16067533], dtype=float32),
#   'logits': array([-1.6532118], dtype=float32),
#   'probabilities': array([0.8393247 , 0.16067535], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08159558], dtype=float32),
#   'logits': array([-2.4208627], dtype=float32),
#   'probabilities': array([0.91840446, 0.08159559], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10191708], dtype=float32),
#   'logits': array([-2.1761029], dtype=float32),
#   'probabilities': array([0.8980829 , 0.10191708], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25681102], dtype=float32),
#   'logits': array([-1.0626098], dtype=float32),
#   'probabilities': array([0.743189  , 0.25681102], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34176964], dtype=float32),
#   'logits': array([-0.65541804], dtype=float32),
#   'probabilities': array([0.6582304 , 0.34176967], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28193], dtype=float32),
#   'logits': array([-0.93490833], dtype=float32),
#   'probabilities': array([0.71807003, 0.28192997], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpd7rd69kf
# INFO:tensorflow:Using config: {'_tf_random_seed': None, '_is_chief': True, '_task_id': 0, '_keep_checkpoint_max': 5, '_train_distribute': None, '_protocol': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa515dd4518>, '_evaluation_master': '', '_save_summary_steps': 100, '_service': None, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpd7rd69kf', '_eval_distribute': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_device_fn': None, '_task_type': 'worker', '_num_worker_replicas': 1, '_num_ps_replicas': 0, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_experimental_distribute': None}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-eb767abc56a5> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func, steps=1000)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1152       worker_hooks.extend(input_hooks)
#    1153       estimator_spec = self._call_model_fn(
# -> 1154           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1155       global_step_tensor = training_util.get_global_step(g)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1110
#    1111     logging.info('Calling model_fn.')
# -> 1112     model_fn_results = self._model_fn(features=features, **kwargs)
#    1113     logging.info('Done calling model_fn.')
#    1114
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     520           input_layer_partitioner=input_layer_partitioner,
#     521           config=config,
# --> 522           batch_norm=batch_norm)
#     523
#     524     super(DNNClassifier, self).__init__(
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     285         input_layer_partitioner=input_layer_partitioner,
#     286         batch_norm=batch_norm)
# --> 287     logits = logit_fn(features=features, mode=mode)
#     288
#     289     if use_tpu:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     100         input_layer_partitioner,
#     101         batch_norm,
# --> 102         name='dnn')
#     103     return dnn_model(features, mode)
#     104
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     127     if feature_column_lib.is_feature_column_v2(feature_columns):
#     128       self._input_layer = feature_column_lib.DenseFeatures(
# --> 129           feature_columns=feature_columns, name='input_layer')
#     130     else:
#     131       self._input_layer = feature_column.InputLayer(
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#     364             'Items of feature_columns must be a DenseColumn. '
#     365             'You can wrap a categorical column with an '
# --> 366             'embedding_column or indicator_column. Given: {}'.format(column))
#     367
#     368   @property
#
# ValueError: Items of feature_columns must be a DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbnqz8ej8
# INFO:tensorflow:Using config: {'_tf_random_seed': None, '_is_chief': True, '_task_id': 0, '_keep_checkpoint_max': 5, '_train_distribute': None, '_protocol': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa535c41f60>, '_evaluation_master': '', '_save_summary_steps': 100, '_service': None, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpbnqz8ej8', '_eval_distribute': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_device_fn': None, '_task_type': 'worker', '_num_worker_replicas': 1, '_num_ps_replicas': 0, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_experimental_distribute': None}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:2997: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpbnqz8ej8/model.ckpt.
# INFO:tensorflow:loss = 7.148276, step = 1
# INFO:tensorflow:global_step/sec: 164.255
# INFO:tensorflow:loss = 6.4239454, step = 101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 195.182
# INFO:tensorflow:loss = 6.2130494, step = 201 (0.506 sec)
# INFO:tensorflow:global_step/sec: 208.24
# INFO:tensorflow:loss = 2.9580622, step = 301 (0.482 sec)
# INFO:tensorflow:global_step/sec: 209.497
# INFO:tensorflow:loss = 5.2537127, step = 401 (0.482 sec)
# INFO:tensorflow:global_step/sec: 223.498
# INFO:tensorflow:loss = 3.0773048, step = 501 (0.442 sec)
# INFO:tensorflow:global_step/sec: 196.865
# INFO:tensorflow:loss = 3.3071015, step = 601 (0.505 sec)
# INFO:tensorflow:global_step/sec: 104.397
# INFO:tensorflow:loss = 5.8016124, step = 701 (0.963 sec)
# INFO:tensorflow:global_step/sec: 184.078
# INFO:tensorflow:loss = 7.927376, step = 801 (0.536 sec)
# INFO:tensorflow:global_step/sec: 192.843
# INFO:tensorflow:loss = 3.8799405, step = 901 (0.518 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpbnqz8ej8/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.5301514.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, shuffle=False)

# %%
dnn_model.evaluate(eval_input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-22T22:08:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbnqz8ej8/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-22-22:08:33
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.70866144, accuracy_baseline = 0.65748036, auc = 0.787666, auc_precision_recall = 0.6186036, average_loss = 0.53909737, global_step = 1000, label/mean = 0.34251967, loss = 5.2665663, precision = 0.5619048, prediction/mean = 0.40725344, recall = 0.6781609
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpbnqz8ej8/model.ckpt-1000
# {'accuracy': 0.70866144,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.787666,
#  'auc_precision_recall': 0.6186036,
#  'average_loss': 0.53909737,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2665663,
#  'precision': 0.5619048,
#  'prediction/mean': 0.40725344,
#  'recall': 0.6781609}

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-22T22:08:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbnqz8ej8/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-22-22:08:40
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.70866144, accuracy_baseline = 0.65748036, auc = 0.787666, auc_precision_recall = 0.6186036, average_loss = 0.53909737, global_step = 1000, label/mean = 0.34251967, loss = 5.2665663, precision = 0.5619048, prediction/mean = 0.40725344, recall = 0.6781609
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpbnqz8ej8/model.ckpt-1000
# {'accuracy': 0.70866144,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.787666,
#  'auc_precision_recall': 0.6186036,
#  'average_loss': 0.53909737,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2665663,
#  'precision': 0.5619048,
#  'prediction/mean': 0.40725344,
#  'recall': 0.6781609}
